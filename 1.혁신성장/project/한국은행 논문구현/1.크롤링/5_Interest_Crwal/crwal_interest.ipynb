# %%
import requests
from bs4 import BeautifulSoup
kosdaq_result=[]
for i in range(1,697):
    
    url=f"https://finance.naver.com/marketindex/interestDailyQuote.nhn?marketindexCd=IRR_CALL&page={i}"
    resp=requests.get(url)
    soup=BeautifulSoup(resp.text)
    li=soup.select('div.section_exchange2 tr')
    
    for l in li:
        if l.find('td',class_='date') is None:
            continue
        kosdaq_result.append({
            'date':l.find_all('td')[0].text.strip(),
            'num':l.find_all('td')[1].text,
            'updown':l.find_all('td')[3].text.strip()
        })
kosdaq_result
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file C:\ProgramData\Anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# [{'date': '2020.08.13', 'num': '0.49', 'updown': '0.00%'},
#  {'date': '2020.08.12', 'num': '0.49', 'updown': '+ 4.26%'},
#  {'date': '2020.08.11', 'num': '0.47', 'updown': '0.00%'},
#  {'date': '2020.08.10', 'num': '0.47', 'updown': '-6.00%'},
#  {'date': '2020.08.07', 'num': '0.50', 'updown': '+ 2.04%'},
# ...

# %%
import pandas as pd
p=pd.DataFrame(kosdaq_result)

# %%
p
# Out:
#             date   num   updown
# 0     2020.08.13  0.49    0.00%
# 1     2020.08.12  0.49  + 4.26%
# 2     2020.08.11  0.47    0.00%
# 3     2020.08.10  0.47   -6.00%
# 4     2020.08.07  0.50  + 2.04%
# ...          ...   ...      ...
# 4846  2001.01.31  5.27   -0.19%
# 4847  2001.01.30  5.28   -0.19%
# 4848  2001.01.29  5.29  + 0.95%
# 4849  2001.01.26  5.24  + 0.77%
# 4850  2001.01.22  5.20   -1.52%
#
# [4851 rows x 3 columns]

# %%
p.to_csv("pp.csv",header=False,index=False)

# %%
# 이후에 pp.csv의 오른쪽 column을 추가해 줘야함
